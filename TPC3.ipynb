# %%
#ADIVINHA O NÚMERO!
# O computador tenta adivinhar o número que o jogador pensou!
print ("INÍCIO DO JOGO!")
n= int(input("Escolhe um número de 0 a 100"))
tentativas = 0
from random import randint
resposta = randint(0, 100)
while resposta != n:
    from random import randint
    resposta = randint(0, 100)
    print("O número que o computador escolheu foi", resposta, ".")
    tentativas= tentativas + 1
    if resposta > n:
        print("O número escolhido pelo jogador é menor.")
    elif resposta < n:
        print("O número escolhido pelo jogador é maior.")
    else:
        print("O computador está de parabéns!. Este acertou o número em", tentativas, "tentativas. \nFIM DO JOGO!")
# Out:
# INÍCIO DO JOGO!
# O número que o computador escolheu foi 39 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 15 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 97 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 23 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 40 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 26 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 91 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 71 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 24 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 34 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 86 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 95 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 64 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 4 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 67 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 38 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 93 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 71 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 12 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 59 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 47 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 83 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 25 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 27 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 42 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 93 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 91 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 23 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 82 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 23 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 7 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 44 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 36 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 12 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 4 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 33 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 66 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 87 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 59 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 8 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 85 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 49 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 42 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 84 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 5 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 93 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 53 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 33 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 7 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 3 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 11 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 82 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 75 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 14 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 79 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 76 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 94 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 6 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 38 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 74 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 89 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 51 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 25 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 3 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 71 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 52 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 11 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 53 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 36 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 94 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 81 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 29 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 76 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 38 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 39 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 54 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 92 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 62 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 82 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 67 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 33 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 0 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 21 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 82 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 52 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 56 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 88 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 67 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 4 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 71 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 29 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 33 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 83 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 44 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 15 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 56 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 14 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 35 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 38 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 64 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 76 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 92 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 96 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 25 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 87 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 96 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 58 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 24 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 78 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 18 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 76 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 23 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 21 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 12 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 83 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 9 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 21 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 87 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 28 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 19 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 17 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 67 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 80 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 38 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 61 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 63 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 61 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 96 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 25 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 85 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 89 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 10 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 25 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 70 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 65 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 55 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 59 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 40 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 60 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 90 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 44 .
# O número escolhido pelo jogador é maior.
# O número que o computador escolheu foi 100 .
# O computador está de parabéns!. Este acertou o número em 142 tentativas.
# FIM DO JOGO!

# %%
# ADIVINHA O NÚMERO!
# O jogador tenta adivinhar o número que o computador pensou!
print ("INÍCIO DO JOGO!")
from random import randint
resposta = randint(0, 100)
tentativas = 0
while n != resposta:
    n= int(input("Escolhe um número de 0 a 100."))
    tentativas= tentativas + 1
    if n > resposta:
        print("O número que o computador escolheu é menor.")
    elif n < resposta:
        print("O número que o computador escolheu é maior.")
    else:
        print("Parabéns! Esse foi o número que o computador escolheu. Acertas te em", tentativas, "tentativas. \nFIM DO JOGO!")
# Out:
# INÍCIO DO JOGO!
# O número que o computador escolheu é menor.
# O número que o computador escolheu é maior.
# O número que o computador escolheu é maior.
# Parabéns! Esse foi o número que o computador escolheu. Acertas te em 4 tentativas.
# FIM DO JOGO!
