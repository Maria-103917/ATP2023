# %%
def lerficheiro():
    file = open("diabetes_prediction_dataset", "r")
    return file

def distribuicao_por_sexo(file):
    x = 0
    j = 0
    for line in file:
        termos = line.split("\n")
        for termo in termos:
            t = termo.split(",")
            if t[0]== "female" and t[8] =="1":
                x = x + 1
            elif t[0] == "Male" and t[8] == "1":
                j = j +1
    file.close()
    doentes = j + x
    print ("Distribuição da doença pelo sexo feminino:", (x/doentes)*100, "%")
    print ("Distribuição da doença pelo sexo masculino:", (j/doentes)*100, "%")

def distribuicao_por_escalõesetários(file):
    x = 0
    a = 0
    s = 0
    b = 0
    c = 0
    e = 0
    f = 0
    d = 0
    g = 0
    h = 0
    j = 0
    k = 0
    l = 0
    i = 0
    for line in file:
        termos = line.split("\n")
        for termo in termos:
            t = termo.split(",")
            if int(t[1])>= 0 and int(t[1])<= 10 :
                x = x + 1
                if t[8] == "1":
                    a = a + 1
            elif int(t[1])> 10 and int(t[1])<= 24:
                s = s+ 1
                if t[8] == "1":
                    b = b + 1
            elif int(t[1])> 24 and int(t[1])<= 29:
                c = c + 1
                if t[8] == "1":
                    d = d + 1
            elif int(t[1])> 29 and int(t[1])<= 34:
                e = e + 1
                if t[8] == "1":
                    f = f + 1
            elif int(t[1])> 34 and int(t[1])<= 39:
                g = g + 1
                if t[8] == "1":
                    h = h + 1
            elif int(t[1])> 39 and int(t[1])<= 44:
                i = i + 1
                if t[8] == "1":
                    j = j + 1
            else:
                k = k +1
                if t[8]=="1":
                    l = l + 1
    file.close()
    print ("Distribuição da doença no escalão etário [0,10]:", a/x, "%")
    print ("Distribuição da doença no escalão etário [11,24]:", b/s, "%")
    print ("Distribuição da doença no escalão etário [25,29]:", d/c, "%")
    print ("Distribuição da doença no escalão etário [30,34]:", f/e, "%")
    print ("Distribuição da doença no escalão etário [34,39]:", h/g, "%")
    print ("Distribuição da doença no escalão etário [40,44]:", j/i, "%")
    print ("Distribuição da doença no escalão etário [44,100]:", l/k, "%")
