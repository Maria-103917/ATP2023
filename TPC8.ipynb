# %%
#TPC8:Testede aferição

#tpc-1:
#a)
 def naocomuns(lista1, lista2):
    return [e for e in lista1 if e not in lista2] + [e for e in lista2 if e not in lista1]

#b)
def MaisDe3Letras(texto):
    return [e for e in texto.split(" ") if len(e)>3]

#c)
def pares(lista):
    return [(i + 1, e) for e in lista, i == -1 ]
print(pares(lista1))

def pares1(list):
    res = []
    i = -1
    for e in list:
        i = i + 1
        res.append((i,e))
    return res

#tpc-2:
#a)
def strCount(s, subs):
    x = 0 
    cont = 0
    while x < len(s):
        j = 0
        while j < len(subs) and s[x] == subs[j]:
            j = j + 1
            x = x + 1
        if j == len(subs):
            cont = cont + 1
        x = x + 1
    return cont

#b)
  def produtoM32(lista):
    listaB = []
    j = 0
    condiçao = True
    while j < len(lista) and condiçao:
        i = 0
        condiçao = False
        while i < len(lista) - 1:
            if lista [i]> lista[i+1]:
                aux = lista[i + 1]
                lista[i + 1]= lista[i]
                lista[i] = aux
                condiçao = True
            i = i +1
        j = j +1
    listaB = lista
    res = listaB[0]*listaB[1]*listaB[2]
    return res

#c)
def reduxInt(n):
    x = str(n)
    while len(str(x)) != 1:
        elem = 0
        j = 0
        while j < len(x):
            elem = elem + int(x[j])
            j = j + 1
        x = str(elem)
    return elem

#d)
def myIndexOf(s1, s2):
    x = 0 
    condiçao = True
    while x < len(s1) and condiçao:
        j = 0
        while j < len(s2) and s1[x] == s2[j]:
            j = j + 1
            x = x + 1
            if j == len(s2):
                print(x - len(s2))
                condiçao = False    
        x = x + 1 

#tpc-3:
#a)
def quantosPost(redeSocial):
    cont = 0
    for e in redeSocial:
        cont = cont + 1 
    return cont

#b)
def postsAutor(redeSocial, autor):
    lista = []
    for post in redeSocial:
        if post['autor'] == autor:
            lista.append(post)
    return  lista

#c)
def autores(redeSocial):
    valores = sorted(redeSocial, key=lambda x: x['autor'])
    return valores

#d)
def insPost(redeSocial, conteudo, autor, dataCriacao, comentarios):
    n = len(redeSocial) + 1
    novoPost = {
        'id': "p" + str(n),  
        'conteudo': conteudo,   
        'autor': autor,
        'dataCriacao': dataCriacao,
        'comentarios': comentarios
    }
    
    redeSocial.append(novoPost)  
    return redeSocial 

#e)
def remPost(redeSocial, id):
    for post in redeSocial:
        if post['id'] == id:
            redeSocial.remove(post)
    return redeSocial

#f)
def postsPorAutor(redeSocial):
    distrib = {}
    for post in redeSocial:
        elem = post['autor'] 
        if elem in distrib:
            distrib[elem] = distrib[elem] + 1
        else:
            distrib[elem] = 1
    return distrib

#g)
def comentadoPor(redeSocial, autor):
    lista = []
    for post in redeSocial:
        elem = post['comentarios']
        for x in elem:
            if x['autor'] == autor:
                lista.append(post)
    return lista
